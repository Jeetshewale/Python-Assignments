# %%
print("Enter the activity hours: ")
a=int(input("Enter self study hours: "))
b=int(input("Enter college hours: "))
c=int(input("Enter family hours: "))
d=int(input("Enter mobile hours: "))
e=int(input("Enter tv hours: "))
prod=a+b+c
non_prod=d+e
print("Productivity hours: ",prod)
print("Non-productivity hours: ",non_prod)
# Out:
# Enter the activity hours:
# Enter self study hours: 5
# Enter college hours: 7
# Enter family hours: 6
# Enter mobile hours: 2
# Enter tv hours: 3
# Productivity hours:  18
# Non-productivity hours:  5
