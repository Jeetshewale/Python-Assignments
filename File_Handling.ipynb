# %% [markdown]
# 1.Write a program to open a file named python stored on my desktop
#
# ---

# %%
f=open("Desktop\\python")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-032cf8fe67cc> in <module>
# ----> 1 f=open("Desktop\\python")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Desktop\\python'

# %% [markdown]
# 2.Write a program to read first 10 characters from a file named python

# %%
f=open("Desktop\\python")
data=f.read(10)
print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-006667dbe673> in <module>
# ----> 1 f=open("Desktop\\python")
#       2 data=f.read(10)
#       3 print(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Desktop\\python'

# %% [markdown]
# 3.Delete the file

# %%
import os 
os.remove("python")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-55cf92ea9e67> in <module>
#       1 import os
# ----> 2 os.remove("python")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'python'
